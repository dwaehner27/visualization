# %%
import pandas as pd

# %%
chicago_path = "Resources/chicago.csv"
chicago_df = pd.read_csv(chicago_path)
nyc_path = "Resources/nyc.csv"
nyc_df = pd.read_csv(nyc_path)
seattle_path = "Resources/seattle_listings.csv"
seattle_df = pd.read_csv(seattle_path)

# %%
chicago_df.head()
# Out:
#    Unnamed: 0     id                                               name  \
# 0           0   2384  Hyde Park - Walk to UChicago, 10 min to McCormick
# 1           1   4505  394 Great Reviews. 127 y/o House. 40 yds to tr...
# 2           2   7126                Tiny Studio Apartment 94 Walk Score
# 3           3   9811                      Barbara's Hideaway - Old Town
# 4           4  10610                   3 Comforts of Cooperative Living
#
#    host_id         host_name   neighbourhood  latitude  longitude  \
# 0     2613           Rebecca       Hyde Park  41.78790  -87.58780
# 1     5775  Craig & Kathleen  South Lawndale  41.85495  -87.69696
# 2    17928             Sarah       West Town  41.90289  -87.68182
# 3    33004       At Home Inn    Lincoln Park  41.91769  -87.63788
# 4     2140              Lois       Hyde Park  41.79612  -87.59261
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     60               2                178  2019-12-15
# 1  Entire home/apt    105               2                395  2020-07-14
# 2  Entire home/apt     60               2                384  2020-03-08
# 3  Entire home/apt     65               4                 49  2019-10-23
# 4     Private room     21               1                 44  2020-02-14
#
#    availability_365
# 0               353
# 1               155
# 2               321
# 3               300
# 4               168

# %%
nyc_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
seattle_df.head()
# Out:
#         id                           listing_url     scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  2.020000e+13     1/4/2016
# 1   953595   https://www.airbnb.com/rooms/953595  2.020000e+13     1/4/2016
# 2  3308979  https://www.airbnb.com/rooms/3308979  2.020000e+13     1/4/2016
# 3  7421966  https://www.airbnb.com/rooms/7421966  2.020000e+13     1/4/2016
# 4   278830   https://www.airbnb.com/rooms/278830  2.020000e+13     1/4/2016
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
# 2  New modern house built in 2013.  Spectacular s...                none
# 3  A charming apartment that sits atop Queen Anne...                none
# 4  Cozy family craftman house in beautiful neighb...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0                                                NaN  ...                10.0
# 1  Queen Anne is a wonderful, truly functional vi...  ...                10.0
# 2  Upper Queen Anne is a charming neighborhood fu...  ...                10.0
# 3                                                NaN  ...                 NaN
# 4  We are in the beautiful neighborhood of Queen ...  ...                 9.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN         WASHINGTON                f
# 1                f     NaN         WASHINGTON                f
# 2                f     NaN         WASHINGTON                f
# 3                f     NaN         WASHINGTON                f
# 4                f     NaN         WASHINGTON                f
#
#   cancellation_policy  require_guest_profile_picture  \
# 0            moderate                              f
# 1              strict                              t
# 2              strict                              f
# 3            flexible                              f
# 4              strict                              f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              2
# 1                                t                              6
# 2                                f                              2
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month
# 0              4.07
# 1              1.48
# 2              1.15
# 3               NaN
# 4              0.89
#
# [5 rows x 92 columns]

# %%
list(chicago_df.columns)
# Out:
# ['Unnamed: 0',
#  'id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'availability_365']

# %%
chicago_revised = chicago_df[["id","name","host_id","host_name","neighbourhood","latitude","longitude","room_type","price","minimum_nights","number_of_reviews","last_review","availability_365"]]
chicago_revised.head()
# Out:
#       id                                               name  host_id  \
# 0   2384  Hyde Park - Walk to UChicago, 10 min to McCormick     2613
# 1   4505  394 Great Reviews. 127 y/o House. 40 yds to tr...     5775
# 2   7126                Tiny Studio Apartment 94 Walk Score    17928
# 3   9811                      Barbara's Hideaway - Old Town    33004
# 4  10610                   3 Comforts of Cooperative Living     2140
#
#           host_name   neighbourhood  latitude  longitude        room_type  \
# 0           Rebecca       Hyde Park  41.78790  -87.58780     Private room
# 1  Craig & Kathleen  South Lawndale  41.85495  -87.69696  Entire home/apt
# 2             Sarah       West Town  41.90289  -87.68182  Entire home/apt
# 3       At Home Inn    Lincoln Park  41.91769  -87.63788  Entire home/apt
# 4              Lois       Hyde Park  41.79612  -87.59261     Private room
#
#    price  minimum_nights  number_of_reviews last_review  availability_365
# 0     60               2                178  2019-12-15               353
# 1    105               2                395  2020-07-14               155
# 2     60               2                384  2020-03-08               321
# 3     65               4                 49  2019-10-23               300
# 4     21               1                 44  2020-02-14               168

# %%
chicago_revised.to_csv("Resources/chicago_clean.csv")

# %%
chicago_for_pins = chicago_revised[["name", "latitude","longitude","price", "minimum_nights"]]
chicago_for_pins1 = chicago_for_pins.loc[chicago_for_pins["price"]>350]
chicago_for_pins1
# Out:
#                                                    name  latitude  longitude  \
# 40             Family Style Home-walk to Aragon/Riviera  41.96924  -87.65807
# 62                      Chicago Lakefront Sailing Yacht  41.85467  -87.61417
# 64                  Drop-dead fab on the Lake  2bd/2bth  41.94284  -87.63919
# 123                     Lincoln Park Single Family Home  41.92913  -87.66921
# 135                      The Biddle House (WHOLE HOUSE)  41.91406  -87.63934
# ...                                                 ...       ...        ...
# 6166  River North's chic 3BD, close to everything do...  41.88988  -87.63452
# 6210                  Only Urban Beach House In Chicago  42.00669  -87.65986
# 6263        Sleeps 10+ Close to South Loop and Downtown  41.83234  -87.62093
# 6378   Sundrenched Northeast Corner Unit in South Loop.  41.85973  -87.62352
# 6394  Two story Penthouse w private Rooftop & Great ...  41.85584  -87.62404
#
#       price  minimum_nights
# 40      764               1
# 62      495               2
# 64      490               1
# 123     511               2
# 135     401               4
# ...     ...             ...
# 6166    734               2
# 6210    425               5
# 6263    389               3
# 6378    500               2
# 6394    493               2
#
# [386 rows x 5 columns]

# %%
chicago_for_pins1.to_csv("Resources/chicago_pins.csv")

# %%
list(nyc_df.columns)
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365']

# %%
nyc_revised = nyc_df[["id","name","host_id","host_name","neighbourhood","latitude","longitude","room_type","price","minimum_nights","number_of_reviews","last_review","availability_365"]]
nyc_revised.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood  latitude  longitude        room_type  price  \
# 0         John    Kensington  40.64749  -73.97237     Private room    149
# 1     Jennifer       Midtown  40.75362  -73.98377  Entire home/apt    225
# 2    Elisabeth        Harlem  40.80902  -73.94190     Private room    150
# 3  LisaRoxanne  Clinton Hill  40.68514  -73.95976  Entire home/apt     89
# 4        Laura   East Harlem  40.79851  -73.94399  Entire home/apt     80
#
#    minimum_nights  number_of_reviews last_review  availability_365
# 0               1                  9  2018-10-19               365
# 1               1                 45  2019-05-21               355
# 2               3                  0         NaN               365
# 3               1                270  2019-07-05               194
# 4              10                  9  2018-11-19                 0

# %%
nyc_revised.to_csv("Resources/nyc_clean.csv")

# %%
nyc_for_pins = nyc_revised[["name", "latitude","longitude","price", "minimum_nights"]]
nyc_for_pins1 = nyc_for_pins.loc[nyc_for_pins["price"]>700]
nyc_for_pins1
# Out:
#                                                     name  latitude  longitude  \
# 85                   perfect for a family or small group  40.69723  -73.99268
# 496                Luxury 2Bed/2.5Bath Central Park View  40.77350  -73.98697
# 662                   Heart & Soul of Greenwich Village   40.73129  -73.99944
# 691            Luxury Chelsea Townhouse at the High Line  40.74599  -74.00253
# 762            6 Bedroom Landmark West Village Townhouse  40.73301  -74.00268
# ...                                                  ...       ...        ...
# 48343                   Sunny, Spacious 2-bd Chelsea Apt  40.74921  -73.99777
# 48523  Tasteful & Trendy Brooklyn Brownstone, near Train  40.68767  -73.95805
# 48535     Stunning & Stylish Brooklyn Luxury, near Train  40.68245  -73.93417
# 48697         HUGE LUXURY CONDO – INCREDIBLE WATER VIEWS  40.77665  -73.98867
# 48839  Massage Spa. Stay overnight. Authors Artist dr...  40.59866  -73.95661
#
#        price  minimum_nights
# 85       800               1
# 496     2000              30
# 662      850               3
# 691      760               2
# 762     1300               5
# ...      ...             ...
# 48343    750               1
# 48523   1369               1
# 48535   1749               1
# 48697    750               4
# 48839    800               1
#
# [589 rows x 5 columns]

# %%
nyc_for_pins1.to_csv("Resources/nyc_pins.csv")

# %%
list(seattle_df.columns)
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'license',
#  'jurisdiction_names',
#  'instant_bookable',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'reviews_per_month']

# %%
seatle_clean = seattle_df[["id","name","host_id","host_name","neighbourhood","latitude","longitude","room_type","price","minimum_nights","number_of_reviews","last_review","availability_365"]]
seatle_clean
# Out:
#             id                                 name   host_id host_name  \
# 0       241032         Stylish Queen Anne Apartment    956883     Maija
# 1       953595   Bright & Airy Queen Anne Apartment   5177328    Andrea
# 2      3308979  New Modern House-Amazing water view  16708587      Jill
# 3      7421966                   Queen Anne Chateau   9851441     Emily
# 4       278830       Charming craftsman 3 bdm house   1452570     Emily
# ...        ...                                  ...       ...       ...
# 3813   8101950   3BR Mountain View House in Seattle  31148752        Bo
# 3814   8902327    Portage Bay View!-One Bedroom Apt  46566046      Glen
# 3815  10267360    Private apartment view of Lake WA  52791370  Virginia
# 3816   9604740    Amazing View with Modern Comfort!  25522052     Karen
# 3817  10208623            Large Lakefront Apartment  14703116       Gil
#
#      neighbourhood   latitude   longitude        room_type  price  \
# 0       Queen Anne  47.636289 -122.371025  Entire home/apt     85
# 1       Queen Anne  47.639123 -122.365667  Entire home/apt    150
# 2       Queen Anne  47.629724 -122.369483  Entire home/apt    975
# 3       Queen Anne  47.638473 -122.369279  Entire home/apt    100
# 4       Queen Anne  47.632918 -122.372471  Entire home/apt    450
# ...            ...        ...         ...              ...    ...
# 3813       Fremont  47.664295 -122.359170  Entire home/apt    359
# 3814   Portage Bay  47.649552 -122.318309  Entire home/apt     79
# 3815           NaN  47.508453 -122.240607  Entire home/apt     93
# 3816           NaN  47.632335 -122.275530  Entire home/apt     99
# 3817    Queen Anne  47.641186 -122.342085  Entire home/apt     87
#
#       minimum_nights  number_of_reviews last_review  availability_365
# 0                  1                207    1/2/2016               346
# 1                  2                 43  12/29/2015               291
# 2                  4                 20    9/3/2015               220
# 3                  1                  0         NaN               143
# 4                  1                 38  10/24/2015               365
# ...              ...                ...         ...               ...
# 3813               3                  1   9/27/2015                32
# 3814               2                  2  12/24/2015               273
# 3815               1                  0         NaN                88
# 3816               3                  0         NaN               179
# 3817               1                  0         NaN                 7
#
# [3818 rows x 13 columns]

# %%
seatle_for_pins = seatle_clean[["name", "latitude","longitude","price", "minimum_nights"]]
seatle_for_pins1 = seatle_for_pins.loc[seatle_for_pins["price"]>200.00]
seatle_for_pins1
# Out:
#                                      name   latitude   longitude  price  \
# 2     New Modern House-Amazing water view  47.629724 -122.369483    975
# 4          Charming craftsman 3 bdm house  47.632918 -122.372471    450
# 12     Open Plan 2bdr/1bath in Queen Anne  47.635546 -122.373171    245
# 14    Stunning 6 bd in THE BEST Location!  47.639203 -122.365863    461
# 19     Grand Craftsman Home on Queen Anne  47.636025 -122.358694    700
# ...                                   ...        ...         ...    ...
# 3758       Beautiful City Home with Views  47.664626 -122.359772    350
# 3771   Fresh & hip. 3br/2.5ba. deck. new.  47.658831 -122.347966    325
# 3787            Fremont Jet City Townhome  47.658552 -122.348265    260
# 3803       Clean City House, Lots of Beds  47.661131 -122.349238    250
# 3813   3BR Mountain View House in Seattle  47.664295 -122.359170    359
#
#       minimum_nights
# 2                  4
# 4                  1
# 12                 3
# 14                 3
# 19                 3
# ...              ...
# 3758               2
# 3771               1
# 3787               3
# 3803               1
# 3813               3
#
# [457 rows x 5 columns]

# %%
seatle_for_pins1.to_csv("Resources/seattle_pins.csv")
